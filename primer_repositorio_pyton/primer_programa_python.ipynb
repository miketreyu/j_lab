# %%
import math

# %%
var = 26
Var = 82
print (var, Var)
# Out:
# 26 82

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
var2 = "buenos días"
type(var2)
print("var2", var2, type(var2))
# Out:
# var2 buenos días <class 'str'>

# %%
var5 = math.inf
print("var5" , var5 , type(var5))
# Out:
# var5 inf <class 'float'>

# %%
var6 = math.nan
print("var6" , var6 , type(var6))
# Out:
# var6 nan <class 'float'>

# %%
bd = "buenos dias"
type(bd)
print("bd: ", bd, type(bd))

bdsalto = '''buenos
dias'''
print(bdsalto)
bdsalto
# Out:
# bd:  buenos dias <class 'str'>
# buenos
# dias
# 'buenos\ndias'

# %%
var1 = 4
var2 = str(5)
tipo1 = str(type(var1))
tipo2 = str(type(var2))
print(var1, var2, tipo1, tipo2)
# Out:
# 4 5 <class 'int'> <class 'str'>

# %%
var1 = var2 = var3 = 'hola'
print(var1, var2, var3)
# Out:
# hola hola hola

# %%
var4 = 'adios'
var5 = 'agua'
print (var4 == var5)
# Out:
# False
